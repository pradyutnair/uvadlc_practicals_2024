# %% [markdown]
# # Imports

# %%
from modules import *
from mlp_numpy import MLP
import argparse
import numpy as np
import os
from tqdm.auto import tqdm
from copy import deepcopy
from mlp_numpy import MLP
from modules import CrossEntropyModule
import cifar10_utils

import torch
import logging
import matplotlib.pyplot as plt

# %% [markdown]
# # Accuracy and Evaluate Model

# %%
def accuracy(predictions, targets):
    """
    Computes the prediction accuracy, i.e., the average of correct predictions
    of the network.

    Args:
      predictions: 2D float array of size [batch_size, n_classes], predictions of the model (logits)
      targets: 1D int array of size [batch_size], ground truth labels for each sample in the batch
    Returns:
      accuracy: scalar float, the accuracy of predictions between 0 and 1,
                i.e., the average correct predictions over the whole batch
    """

    #######################
    # PUT YOUR CODE HERE  #
    #######################
    # Compute predicted classes
    predicted_class = np.argmax(predictions, axis=1)[0]
    target_class = np.argmax(targets, axis=0)
    # Calculate accuracy
    accuracy = predicted_class == target_class
    #######################
    # END OF YOUR CODE    #
    #######################

    return accuracy



def evaluate_model(model, data_loader):
    """
    Performs the evaluation of the MLP model on a given dataset.

    Args:
      model: An instance of 'MLP', the model to evaluate.
      data_loader: The data loader of the dataset to evaluate.
    Returns:
      avg_accuracy: scalar float, the average accuracy of the model on the dataset.
    """

    #######################
    # PUT YOUR CODE HERE  #
    #######################
    total_correct = 0
    total_samples = 0

    for batch_data, batch_targets in data_loader:
        batch_data = batch_data.astype(np.float32) / 255.0

        # Forward pass
        predictions = model.forward(batch_data)

        # Calculate accuracy for this batch
        batch_correct = accuracy(predictions, batch_targets)
        total_correct += batch_correct
        total_samples += batch_data.shape[0]

    # Compute average accuracy
    avg_accuracy = total_correct / total_samples
    #######################
    # END OF YOUR CODE    #
    #######################

    return avg_accuracy

# %% [markdown]
# # Training

# %%
from assignment1.train_mlp_numpy import evaluate_model
from copy import deepcopy
import numpy as np
seed = 42
data_dir = "../data"
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()
hidden_dims = [128]
batch_size = 128
epochs = 2
lr = 0.1
# Set the random seeds for reproducibility
np.random.seed(seed)
torch.manual_seed(seed)

## Loading the dataset
cifar10 = cifar10_utils.get_cifar10(data_dir)
cifar10_loader = cifar10_utils.get_dataloader(cifar10, batch_size=batch_size,
                                              return_numpy=True)

#######################
# PUT YOUR CODE HERE  #
#######################

# TODO: Initialize model and loss module
# Initialize model and loss module
n_inputs = 3 * 32 * 32  # CIFAR10 images: 3 channels, 32x32 pixels
n_classes = 10
model = MLP(n_inputs, hidden_dims, n_classes)
# Print model
print(model)
loss_module = CrossEntropyModule()
# TODO: Training loop including validation
val_accuracies = []
# TODO: Test best model
test_accuracy = 0.0
# TODO: Add any information you might want to save for plotting
logging_dict = {'losses': [], 'val_accuracies': [],
                 'test_accuracy': 0.0, 'best_validation_accuracy': 0.0}

# Initialize best model
best_model = None
best_validation_accuracy = 0.0
train_acc = []
for epoch in tqdm(range(epochs), desc='Training'):
  # Training
  for batch_data, batch_targets in cifar10_loader['train']:
      # Flatten data
      batch_data = batch_data.reshape(batch_data.shape[0], -1)
      batch_data = batch_data.astype(np.float32) / 255.0  # Normalize data

      # Forward pass
      predictions = model.forward(batch_data)
      logger.debug(f"predictions.shape: {predictions.shape}")
      logger.debug(f"batch_targets.shape: {batch_targets.shape}")

      # Calculate loss
      loss = loss_module.forward(predictions, batch_targets)
      
      # Calculate accuracy 
      acc = accuracy(predictions, batch_targets)
      train_acc.append(acc)
      
      # In the training loop, after calculating loss:
      if len(logging_dict['losses']) % 100 == 0:  # Log every 100 iterations
          logger.info(f"Iteration {len(logging_dict['losses'])}, Training Loss: {loss:.4f}")
      logging_dict['losses'].append(loss)
      
      
      # Backward pass
      dL_dy = loss_module.backward(predictions, batch_targets)
      logger.debug(f"dL_dy.shape: {dL_dy.shape}")
      model.backward(dL_dy)
      
      # Update model parameters using SGD
      for layer in model.layers:
          if hasattr(layer, 'params'):
              logger.debug(f"Layer {layer}")
              # Update parameters
              for param_name, param in layer.params.items():
                  logger.debug(f"param_name: {param_name}")
                  logger.debug(f"param.shape: {param.shape}")
                  logger.debug(f"layer.grads[{param_name}].shape: {layer.grads[param_name].shape}")
                  #print(f"Initial weights", param[:5])
                  param -= lr * layer.grads[param_name]
                  #print(f"Updated weights", param[:5])

#   # Validation data
#   for val_data, val_targets in cifar10_loader['validation']:
#     # Flatten data
#     val_data = val_data.reshape(val_data.shape[0], -1)
#     val_data = val_data.astype(np.float32) / 255.0  # Normalize data
#     # One-hot encode targets
#     val_targets_onehot = np.zeros((val_targets.size, n_classes))
#     val_targets_onehot[np.arange(val_targets.size), val_targets] = 1
#     # Check shapes
#     assert val_targets_onehot.shape == (val_data.shape[0], n_classes), "Validation data shape mismatch"
#     # Evaluate model on validation set
#     val_accuracy = evaluate_model(model, zip(val_data, val_targets_onehot))
#     if len(val_accuracies) % 100 == 0:  # Log every 100 iterations
#         logger.info(f"Validation accuracy: {val_accuracy:.4f}")
#     val_accuracies.append(val_accuracy)
# 
#     if best_model is None or val_accuracy > max(val_accuracies):
#         best_validation_accuracy = val_accuracy
#         best_model = deepcopy(model)
# 
# # Evaluate best model on test set
# for test_data, test_targets in cifar10_loader['test']:
#   # Flatten data
#   test_data = test_data.reshape(test_data.shape[0], -1)
#   test_data = test_data.astype(np.float32) / 255.0  # Normalize data
#   # One-hot encode targets
#   test_targets_onehot = np.zeros((test_targets.size, n_classes))
#   test_targets_onehot[np.arange(test_targets.size), test_targets] = 1
#   # Check shapes
#   assert test_targets_onehot.shape == (test_data.shape[0], n_classes), "Test data shape mismatch"
#   # Evaluate model on test set
#   #test_accuracy = evaluate_model(best_model, zip(test_data, test_targets_onehot))
# 
# # Save logging information
# logging_dict['val_accuracies'] = val_accuracies
# logging_dict['test_accuracy'] = test_accuracy
# logging_dict['best_validation_accuracy'] = best_validation_accuracy
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
#
#
# MLP with:
# <modules.LinearModule object at 0x299b7d910>
# <modules.ELUModule object at 0x2a0aa37a0>
# alpha: 1.0
# <modules.LinearModule object at 0x2a286ec30>
# Training:   0%|          | 0/2 [00:00<?, ?it/s]
# 2024-11-01 08:28:22,846 - INFO - Iteration 0, Training Loss: 2.3035
# 2024-11-01 08:28:25,262 - INFO - Iteration 100, Training Loss: 2.2969
# 2024-11-01 08:28:27,131 - INFO - Iteration 200, Training Loss: 2.2903
# 2024-11-01 08:28:28,998 - INFO - Iteration 300, Training Loss: 2.2803
# 2024-11-01 08:28:30,808 - INFO - Iteration 400, Training Loss: 2.2795
# 2024-11-01 08:28:33,193 - INFO - Iteration 500, Training Loss: 2.2660
# 2024-11-01 08:28:35,131 - INFO - Iteration 600, Training Loss: 2.2553
# 2024-11-01 08:28:36,970 - INFO - Iteration 700, Training Loss: 2.2453

# %%
model

# %%
np.mean(train_acc)
# Out:
# 0.06552706552706553

# %%
for val_data, val_targets in cifar10_loader['validation']:
    # Flatten data
    val_data = val_data.reshape(val_data.shape[0], -1)
    val_data = val_data.astype(np.float32) / 255.0  # Normalize data
    batch_data = zip(val_data, val_targets_onehot)
    total_correct = 0
    total_samples = 0
    for batch_data, batch_targets in batch_data:
        batch_data = batch_data.astype(np.float32) / 255.0
    
        # Forward pass
        predictions = model.forward(batch_data)
        print(f"Predictions: {predictions}")
        #print(f"Batch targets: {batch_targets}")
        #print(predictions.shape)
        
        # Print predictions
        print(f"Prediction: {np.argmax(predictions, axis=1)[0]}")
        print(f"Target: {np.argmax(batch_targets, axis=0)}")
    
        # Calculate accuracy for this batch
        batch_correct = np.argmax(predictions, axis=1)[0] == np.argmax(batch_targets, axis=0)
        print(batch_correct)
        total_correct += batch_correct
        total_samples += batch_data.shape[0]

total_correct
# Out:
# Predictions: [[0.09932518 0.09999409 0.10083763 0.10035344 0.09993514 0.10282997
#   0.09926299 0.09781014 0.09938503 0.10026638]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09925303 0.10000199 0.10083958 0.10036804 0.09996894 0.10286053
#   0.09928968 0.09781995 0.09934758 0.1002507 ]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09929778 0.09999715 0.10083492 0.10036349 0.09994685 0.10284503
#   0.09927636 0.09780878 0.09937055 0.10025908]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09932788 0.09998181 0.10084405 0.10037267 0.09993628 0.10284476
#   0.09925734 0.09780476 0.09938875 0.10024169]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09931461 0.09999113 0.100845   0.10035648 0.09994319 0.10284279
#   0.09926864 0.09781228 0.0993753  0.10025058]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09933494 0.10000547 0.10082688 0.10034495 0.09992355 0.10281978
#   0.09926085 0.09779368 0.09940969 0.10028022]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09928121 0.09998977 0.10084777 0.10036895 0.09996054 0.1028514
#   0.09928222 0.0978203  0.09935209 0.10024575]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09939736 0.09999371 0.10083278 0.10033827 0.09989833 0.10281167
#   0.09922768 0.09778051 0.0994427  0.10027699]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09934508 0.09999012 0.10083628 0.10035334 0.09992793 0.1028323
#   0.099254   0.09780005 0.0994019  0.10025901]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09937567 0.09998904 0.10083097 0.10034491 0.09991073 0.10281875
#   0.099239   0.09778597 0.09943565 0.10026931]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.0993403  0.09999635 0.1008346  0.10035194 0.09992765 0.10282821
#   0.09925785 0.09780279 0.09939587 0.10026444]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.0993479  0.09999815 0.10083149 0.10034607 0.09991832 0.10282299
#   0.09925288 0.097792   0.09941615 0.10027405]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.0992841  0.09999435 0.1008432  0.10036435 0.09995597 0.10284888
#   0.09927979 0.0978159  0.09936197 0.10025149]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09928139 0.09998702 0.10084996 0.10036492 0.0999594  0.10284671
#   0.0992821  0.09782593 0.09935181 0.10025078]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.0992605  0.09999692 0.100838   0.10036805 0.0999627  0.10286263
#   0.09929158 0.09781632 0.09935454 0.10024877]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.0992897  0.09999258 0.1008413  0.10036642 0.09995034 0.10285128
#   0.09927548 0.09781109 0.09936943 0.10025238]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09932327 0.09998996 0.10083569 0.10035433 0.0999349  0.10283103
#   0.09926329 0.09780894 0.09939121 0.10026738]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09924784 0.09999591 0.10084168 0.10037673 0.09997296 0.10286933
#   0.09929629 0.09782581 0.09933374 0.10023972]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09930095 0.10000431 0.1008287  0.1003586  0.09993941 0.10282853
#   0.09927485 0.09780415 0.0993867  0.10027381]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09932026 0.09998768 0.10084349 0.10036197 0.09994073 0.10283866
#   0.09926755 0.09781642 0.09937103 0.10025221]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09931253 0.10000553 0.10082319 0.10035229 0.09994085 0.10283618
#   0.09926419 0.09779818 0.09939489 0.10027217]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09931758 0.09998889 0.10084295 0.1003604  0.09994234 0.10284093
#   0.09926392 0.09780727 0.09938291 0.10025281]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09932733 0.10000265 0.1008329  0.10034866 0.09993149 0.10282898
#   0.09926195 0.09779238 0.09940243 0.10027122]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09928561 0.09999794 0.10083697 0.10036417 0.09995082 0.1028527
#   0.09927828 0.09780937 0.09937073 0.10025341]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09929133 0.100005   0.10083515 0.10035882 0.09994294 0.10284525
#   0.0992776  0.09779891 0.09938055 0.10026445]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09932438 0.10000809 0.10082775 0.10034762 0.09992819 0.10282846
#   0.09926181 0.09779073 0.09940635 0.10027661]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09931742 0.09998775 0.10084413 0.10036157 0.09993842 0.10283813
#   0.09926972 0.09781477 0.09937508 0.10025301]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09928898 0.10000941 0.10083479 0.10035603 0.0999437  0.10284106
#   0.09928251 0.09780723 0.09937002 0.10026627]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09927082 0.09999842 0.10084214 0.10037023 0.09995661 0.1028576
#   0.09928667 0.09781925 0.09934812 0.10025016]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09939163 0.09997682 0.10084331 0.10035312 0.09990981 0.10281553
#   0.09923365 0.09779744 0.09942292 0.10025577]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09936147 0.100002   0.10083067 0.10033996 0.09991694 0.10281546
#   0.09924431 0.09779259 0.09941512 0.10028147]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09931124 0.10000107 0.10083574 0.10035482 0.09993671 0.10283602
#   0.099266   0.09781127 0.09938154 0.10026561]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09935033 0.09998654 0.10084085 0.10035374 0.09992747 0.10283322
#   0.09924932 0.09780459 0.09939877 0.10025517]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09928191 0.09998467 0.10084756 0.10037727 0.0999592  0.10286529
#   0.09927947 0.09782524 0.0993493  0.10023009]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09929107 0.10001152 0.10083266 0.10035715 0.09994696 0.10283946
#   0.09927624 0.09780423 0.09937505 0.10026566]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09929275 0.0999864  0.10084516 0.10037213 0.09995914 0.1028523
#   0.09928167 0.09782106 0.09935378 0.1002356 ]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.0992776  0.09999483 0.10084271 0.10036689 0.09995766 0.10285125
#   0.09928457 0.09782057 0.09935565 0.10024827]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09934298 0.09999749 0.1008343  0.10034857 0.09992528 0.10282915
#   0.09925242 0.09779687 0.09940634 0.1002666 ]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09931479 0.10000082 0.10083554 0.10035244 0.09993916 0.10283459
#   0.09926575 0.09780452 0.09938673 0.10026565]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09933314 0.09998176 0.10084728 0.10035853 0.09993755 0.10283652
#   0.09926075 0.09780656 0.09938755 0.10025035]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09932484 0.09998143 0.10084689 0.10036036 0.0999371  0.10283906
#   0.09926572 0.09780904 0.09938165 0.10025391]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09926014 0.09998803 0.10084905 0.10037985 0.09997376 0.10286923
#   0.09928981 0.09783486 0.09932766 0.10022761]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09932909 0.10000605 0.10082566 0.10034354 0.09992579 0.10282812
#   0.09926044 0.09779313 0.09940856 0.10027961]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09925152 0.10000038 0.10084046 0.10036828 0.09996993 0.10285927
#   0.09929446 0.0978238  0.09934084 0.10025105]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09927315 0.0999946  0.1008437  0.10036827 0.09995868 0.10285761
#   0.09928795 0.09781667 0.09935352 0.10024584]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09933945 0.09998792 0.10084199 0.10035151 0.09993237 0.10283201
#   0.09925908 0.09780518 0.09939025 0.10026023]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09932795 0.09998641 0.10084604 0.10036189 0.09993875 0.10283849
#   0.09925978 0.09780785 0.09938634 0.10024649]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09925583 0.09999281 0.10084781 0.10037376 0.09997185 0.10286284
#   0.09929295 0.0978294  0.09933424 0.10023851]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.0993064  0.09999075 0.10083922 0.10036205 0.09994281 0.10284253
#   0.09927189 0.09780896 0.09938051 0.10025489]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09927195 0.09998672 0.10084712 0.10037834 0.09996499 0.10286112
#   0.09928846 0.09782598 0.09934232 0.10023302]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09926887 0.09999528 0.10084017 0.10036918 0.0999653  0.10285759
#   0.09928822 0.09781764 0.09935307 0.10024467]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09929336 0.0999854  0.10084751 0.10037418 0.09995587 0.10285071
#   0.09927278 0.09782387 0.09935708 0.10023924]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09931022 0.10000179 0.1008335  0.10035124 0.0999365  0.10283392
#   0.0992716  0.097799   0.09938997 0.10027225]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09929102 0.09999678 0.10084152 0.10036133 0.09995074 0.10284113
#   0.09927722 0.09781545 0.09936617 0.10025863]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09931338 0.1000012  0.10083068 0.10035561 0.09993988 0.10284164
#   0.09926701 0.09779475 0.09939511 0.10026075]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09929326 0.09998375 0.10084927 0.10037051 0.09995852 0.10285511
#   0.09927542 0.09781919 0.09935402 0.10024095]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09928485 0.09998987 0.10084064 0.10036804 0.09995591 0.10285633
#   0.09928082 0.09781178 0.09936622 0.10024554]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09930083 0.09998691 0.10084193 0.10036178 0.09994866 0.10285266
#   0.0992764  0.09781015 0.09937517 0.10024552]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09930812 0.09998009 0.10084764 0.10036445 0.09995415 0.10284835
#   0.09927261 0.09782058 0.09936557 0.10023844]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09930418 0.09997424 0.10085823 0.10037573 0.09995916 0.10284711
#   0.09927215 0.09782824 0.09935041 0.10023056]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09934329 0.0999797  0.10084968 0.10036503 0.09992994 0.10282784
#   0.09926589 0.09781441 0.09937167 0.10025255]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.0992934  0.09999099 0.10084231 0.10036561 0.09995223 0.10284692
#   0.09928089 0.09782068 0.09936037 0.10024662]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09928973 0.10000062 0.10083566 0.1003609  0.09994963 0.10284262
#   0.0992759  0.09780868 0.09937485 0.1002614 ]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09932807 0.09999771 0.1008388  0.10034844 0.0999325  0.10282954
#   0.09926044 0.0978088  0.09938795 0.10026775]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09930135 0.09999937 0.10083528 0.10035756 0.09994357 0.10284404
#   0.09927185 0.09780684 0.09937976 0.10026037]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.0992784  0.09999975 0.10084133 0.10036145 0.09995711 0.10284991
#   0.09928552 0.09781376 0.09935769 0.10025509]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09931364 0.09999144 0.10084025 0.10036229 0.09994469 0.10284671
#   0.09926564 0.09780533 0.09938051 0.1002495 ]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.0992552  0.10000986 0.10083062 0.10036913 0.09995676 0.10285641
#   0.09929    0.09781373 0.09936016 0.10025815]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09939956 0.09997862 0.1008423  0.10035087 0.09990596 0.10281737
#   0.09922902 0.09779236 0.09942859 0.10025535]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09928039 0.09999933 0.1008401  0.1003647  0.09995593 0.10285054
#   0.09928089 0.09781464 0.09936136 0.10025212]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.0992981  0.10000695 0.10083097 0.10035743 0.09993998 0.10283619
#   0.09927176 0.0978051  0.099385   0.10026851]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09931566 0.10000626 0.10083321 0.10035015 0.09993623 0.10283724
#   0.09926492 0.09779792 0.0993898  0.10026862]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09933547 0.09999049 0.1008417  0.10035712 0.09993271 0.10283474
#   0.09925908 0.09781163 0.0993812  0.10025586]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09928344 0.09999424 0.10084434 0.10036497 0.09995576 0.10284835
#   0.09928375 0.09781736 0.0993576  0.10025019]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09925854 0.10000164 0.10083519 0.1003738  0.09996122 0.10286635
#   0.09928949 0.09781611 0.09935311 0.10024455]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09930151 0.09999444 0.10084352 0.10036351 0.09994852 0.10284229
#   0.0992739  0.09781564 0.0993666  0.10025007]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.0993277  0.09998595 0.10084686 0.1003614  0.09994184 0.10283496
#   0.09926205 0.09781209 0.09937725 0.10024988]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09930334 0.09999446 0.10084365 0.10037008 0.09995275 0.10284073
#   0.09927353 0.09781551 0.09936293 0.10024302]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.0993108  0.10000298 0.10083454 0.10035561 0.09993414 0.10283732
#   0.09926801 0.09780561 0.0993871  0.10026389]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09932742 0.10000391 0.10083355 0.10034357 0.09992825 0.10282966
#   0.09925544 0.09779797 0.09940423 0.10027599]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09929585 0.10000887 0.10083274 0.1003488  0.09994524 0.10283629
#   0.09927406 0.09780792 0.09937854 0.10027169]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.099311   0.10000724 0.10082484 0.10034829 0.09993882 0.10284268
#   0.09926528 0.09780032 0.0993866  0.10027493]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09926881 0.1000011  0.10083736 0.10036507 0.09996057 0.10285101
#   0.09928391 0.09781883 0.09935522 0.10025813]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.0992974  0.0999966  0.10084026 0.1003613  0.0999515  0.10283664
#   0.09927362 0.09781903 0.09936416 0.10025949]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09929474 0.10000315 0.10083193 0.10035778 0.0999434  0.10284141
#   0.099271   0.09780455 0.09938458 0.10026747]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09935867 0.09997663 0.10084699 0.10036296 0.09992666 0.10283508
#   0.09924763 0.09780566 0.0993968  0.10024292]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09925841 0.1000085  0.10083465 0.10036238 0.09995749 0.10285872
#   0.09929149 0.09781197 0.09935595 0.10026045]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09934724 0.09997213 0.10085431 0.10036761 0.09993158 0.10282866
#   0.09925277 0.09781371 0.09938886 0.10024312]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.0993147  0.09999691 0.10083109 0.1003569  0.09993816 0.10284462
#   0.09926363 0.09779656 0.09939838 0.10025906]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09927434 0.09999699 0.10084009 0.10036311 0.09995527 0.10285353
#   0.09928809 0.09781641 0.09935905 0.10025312]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09934691 0.0999962  0.10083344 0.10034759 0.0999203  0.10282345
#   0.0992557  0.09779488 0.09940871 0.10027281]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09930191 0.09998704 0.10084287 0.10036065 0.09994896 0.10285413
#   0.09927625 0.09780605 0.09937573 0.10024641]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09930795 0.10000569 0.10083118 0.10035138 0.09993823 0.10283241
#   0.09927049 0.09780522 0.09938547 0.10027198]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09931408 0.09999577 0.10083373 0.10035828 0.09993435 0.10284032
#   0.09926717 0.09779939 0.09939446 0.10026246]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09933962 0.10001246 0.10081921 0.10033984 0.09991972 0.10282476
#   0.09925457 0.09778608 0.09941824 0.10028551]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09936921 0.09999892 0.10083294 0.10034934 0.09991086 0.10281558
#   0.09924328 0.09779319 0.0994149  0.10027179]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09931464 0.09999136 0.10083873 0.10036224 0.09994382 0.10284206
#   0.09926745 0.0978031  0.09938728 0.10024932]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09931715 0.10000725 0.10083589 0.10035035 0.0999361  0.10282468
#   0.09926232 0.09780096 0.09938678 0.10027851]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09929295 0.1000061  0.10082738 0.10035478 0.09994344 0.10284699
#   0.09927859 0.09779845 0.09938796 0.10026337]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09933774 0.09998977 0.10084069 0.1003527  0.0999296  0.10282906
#   0.09926096 0.09780294 0.0993911  0.10026543]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09930401 0.09998546 0.10084558 0.10036539 0.09994951 0.10284423
#   0.0992725  0.0978207  0.09936537 0.10024726]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09927027 0.09999866 0.10084482 0.10036526 0.09995934 0.10285226
#   0.0992865  0.09781884 0.09935306 0.10025099]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.099289   0.09999763 0.10084339 0.10036394 0.0999553  0.10284642
#   0.09927681 0.09781359 0.09936335 0.10025057]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09925178 0.09999722 0.10084052 0.10037386 0.09996766 0.1028639
#   0.09929215 0.09782042 0.09934817 0.10024433]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09929373 0.10000488 0.10082895 0.10035736 0.09994174 0.10284147
#   0.09927474 0.09780553 0.09938089 0.10027071]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09927597 0.09998824 0.10085191 0.10037165 0.0999645  0.10286253
#   0.09928759 0.09782516 0.09934179 0.10023066]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09925378 0.09999799 0.10084097 0.10036888 0.09997035 0.10285955
#   0.09929486 0.09782232 0.09934466 0.10024664]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09935746 0.0999732  0.10084968 0.10036404 0.09993302 0.1028395
#   0.09924863 0.09780667 0.09939262 0.10023519]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09935867 0.09998852 0.10083316 0.10035067 0.09992299 0.10282827
#   0.09924609 0.09779802 0.0994132  0.10026041]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09938396 0.0999852  0.10083677 0.10034444 0.09990542 0.10281773
#   0.09923758 0.09778696 0.09943169 0.10027025]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09930142 0.09999595 0.1008367  0.1003611  0.09994523 0.10284398
#   0.09927128 0.09781435 0.09937691 0.10025308]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09927029 0.09999783 0.10084228 0.10036827 0.09996255 0.10286053
#   0.09928621 0.09782054 0.0993473  0.1002442 ]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09933447 0.09999748 0.10083469 0.100352   0.09992717 0.10283209
#   0.09925874 0.09779822 0.09939943 0.10026571]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09929178 0.10001194 0.10082947 0.10035558 0.09994186 0.10284566
#   0.09927252 0.09779711 0.09938512 0.10026896]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09924957 0.10000177 0.10083545 0.10036613 0.0999648  0.10286758
#   0.09929268 0.09781596 0.09935271 0.10025335]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09931696 0.10000931 0.10082694 0.10035065 0.09993258 0.10283736
#   0.0992643  0.09779226 0.09939965 0.10027   ]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09932004 0.09998798 0.10084206 0.10035908 0.09994175 0.10283862
#   0.09926886 0.09781194 0.09937856 0.10025112]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09931373 0.10000264 0.10083002 0.10035461 0.09993793 0.10284026
#   0.09926626 0.09779776 0.09939325 0.10026355]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09928285 0.09999071 0.10084106 0.1003679  0.09995563 0.10285791
#   0.09927992 0.09782162 0.09935696 0.10024542]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.0992829  0.09998977 0.10084651 0.10036887 0.09995508 0.10285722
#   0.09928303 0.09781632 0.09935689 0.1002434 ]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09933155 0.09999005 0.10084104 0.10035629 0.09993097 0.10283654
#   0.09925916 0.09780145 0.0993949  0.10025805]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09930151 0.10000923 0.10082666 0.10035032 0.09993401 0.1028441
#   0.09927425 0.09779502 0.09939608 0.1002688 ]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09932083 0.0999893  0.10084022 0.10036307 0.09994151 0.10284353
#   0.0992633  0.09780671 0.09938451 0.10024703]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09932568 0.10000886 0.10082865 0.10034309 0.09993157 0.1028285
#   0.0992657  0.09779724 0.09939291 0.1002778 ]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09935438 0.09999075 0.10084069 0.10035232 0.09992609 0.10282358
#   0.09925019 0.09780148 0.09940007 0.10026045]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09927439 0.09999552 0.10084382 0.10036979 0.09996501 0.1028559
#   0.09928384 0.09781978 0.09934924 0.1002427 ]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.0992404  0.10000484 0.10083946 0.10037195 0.09997307 0.10286741
#   0.09929938 0.09782286 0.09933485 0.10024576]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09927684 0.09998627 0.10084559 0.10037169 0.09996006 0.10285861
#   0.09928741 0.09782161 0.09935568 0.10023624]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09927073 0.09999317 0.10084429 0.10037266 0.09996256 0.10285909
#   0.09928668 0.09782179 0.09934822 0.10024082]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09933026 0.0999962  0.1008333  0.1003528  0.09993448 0.10283367
#   0.09925955 0.09779948 0.09939775 0.10026252]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09934294 0.09999456 0.10083463 0.1003485  0.09992685 0.10282687
#   0.09925654 0.09779988 0.09940163 0.10026759]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09928695 0.09998636 0.10084954 0.10037197 0.09996127 0.1028537
#   0.09927741 0.09782235 0.09935292 0.10023753]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09925752 0.09999534 0.10083944 0.10037348 0.09996621 0.10286198
#   0.09929062 0.09781984 0.09935281 0.10024275]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09931526 0.10000842 0.10082574 0.10034447 0.09993256 0.10282955
#   0.09926561 0.09779613 0.09940217 0.1002801 ]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09934969 0.09999155 0.10083771 0.10035605 0.09992417 0.10283119
#   0.09925284 0.09779499 0.0994065  0.10025531]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09927785 0.099999   0.10083945 0.10036686 0.09995546 0.10285052
#   0.0992802  0.0978137  0.0993631  0.10025386]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09927641 0.09999696 0.10084431 0.1003663  0.09996009 0.10285023
#   0.09928082 0.0978159  0.09936021 0.10024877]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09924123 0.10000047 0.10083888 0.1003716  0.09997262 0.10286798
#   0.09930064 0.09782215 0.09933982 0.1002446 ]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09936638 0.09998325 0.10083891 0.10035328 0.09991907 0.10283093
#   0.09924434 0.0977968  0.09941303 0.100254  ]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09930213 0.09999204 0.10084749 0.1003601  0.09995186 0.10284059
#   0.0992731  0.09782459 0.0993581  0.10025   ]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09932211 0.09999588 0.10083617 0.10035657 0.09993275 0.10283658
#   0.09926024 0.09779776 0.0993972  0.10026476]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09930181 0.09999769 0.10083984 0.10035725 0.09995193 0.10283265
#   0.09927759 0.09781449 0.09936328 0.10026348]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09929635 0.10000735 0.10083176 0.10035327 0.09994041 0.10283997
#   0.09927341 0.0977988  0.09938639 0.10027228]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09923456 0.10000115 0.10084164 0.10037325 0.09997349 0.10286829
#   0.09930055 0.09782277 0.09933778 0.10024652]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09932406 0.09998304 0.1008488  0.10036107 0.09994044 0.10283803
#   0.09926453 0.09781866 0.09937342 0.10024796]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09930135 0.09998742 0.10084559 0.10036641 0.0999473  0.10285155
#   0.09927413 0.09780591 0.09937734 0.10024301]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09927037 0.09998793 0.10084722 0.10037873 0.09996244 0.1028575
#   0.09928639 0.09781929 0.09935331 0.10023683]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09927987 0.09998275 0.10085164 0.10037703 0.09995902 0.10286065
#   0.09928258 0.09782654 0.09934654 0.10023338]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09932283 0.09999955 0.10083632 0.10035217 0.09993753 0.10283418
#   0.09926227 0.09780385 0.09938685 0.10026446]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09928032 0.10000023 0.10083687 0.10035776 0.09995048 0.10284695
#   0.09928512 0.09780888 0.09936685 0.10026654]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09936378 0.0999823  0.1008427  0.10035518 0.09991713 0.10282338
#   0.09924637 0.09780255 0.09940519 0.10026141]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09930113 0.09997885 0.10085243 0.10037283 0.09995881 0.10285682
#   0.09927355 0.09782153 0.09935768 0.10022637]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09927481 0.09999495 0.10084559 0.10036952 0.09995908 0.10285404
#   0.09928754 0.09782616 0.09934577 0.10024253]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09933099 0.10000274 0.10082628 0.10034865 0.09992335 0.10282681
#   0.09925907 0.09779804 0.09940754 0.10027652]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09928595 0.10000035 0.1008395  0.10036286 0.099953   0.10285279
#   0.09928282 0.09781549 0.09935677 0.10025047]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09932038 0.09998639 0.10084338 0.10035987 0.09993637 0.10283596
#   0.09926606 0.09781399 0.09938022 0.10025736]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09932739 0.09998479 0.10084201 0.100361   0.09993744 0.10283992
#   0.09926071 0.09780696 0.09938791 0.10025186]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09929302 0.09999139 0.10084441 0.10036203 0.09995354 0.10284569
#   0.09927633 0.0978199  0.09936453 0.10024917]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09930997 0.09999946 0.10083137 0.10035208 0.09993751 0.1028402
#   0.09926807 0.09780896 0.09938732 0.10026506]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09932379 0.09998864 0.10084251 0.10035864 0.09993976 0.102836
#   0.09926227 0.09781187 0.09938083 0.10025568]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.0992746  0.09999898 0.10084185 0.10036426 0.09996076 0.10285081
#   0.09928585 0.09781833 0.09935388 0.10025068]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.0993211  0.09999839 0.1008316  0.10035137 0.09993102 0.10283924
#   0.09926256 0.09779869 0.09940271 0.10026332]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09936839 0.09998878 0.10084069 0.10035872 0.09991656 0.10282165
#   0.09924196 0.09780419 0.09940495 0.10025411]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09930335 0.09998935 0.10084696 0.10036059 0.09994971 0.10284246
#   0.09927325 0.09781605 0.09936585 0.10025243]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09928758 0.0999897  0.10083606 0.10037051 0.09994973 0.10286354
#   0.09927567 0.09781701 0.09936887 0.10024133]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09931657 0.10000291 0.10083182 0.10035275 0.09993859 0.10283209
#   0.09926443 0.0978074  0.09938724 0.10026622]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09929375 0.09998951 0.10084479 0.10036565 0.09995296 0.10284934
#   0.0992773  0.09781068 0.09936866 0.10024735]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09929264 0.10000408 0.10082711 0.1003622  0.09994689 0.10284409
#   0.09927503 0.09780722 0.09938138 0.10025935]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09925224 0.10000365 0.10083901 0.10036963 0.09996934 0.10286077
#   0.0992909  0.09782146 0.09934419 0.10024882]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09931605 0.09997963 0.10084784 0.10036789 0.09994798 0.10284941
#   0.0992663  0.09780897 0.09937787 0.10023805]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09934199 0.09998674 0.10083901 0.10035088 0.09993077 0.10282309
#   0.09925786 0.09781133 0.09939461 0.10026373]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09925001 0.10000342 0.10083981 0.10036707 0.09996373 0.1028587
#   0.09929549 0.09781949 0.09934854 0.10025374]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09926034 0.09999192 0.10084407 0.1003743  0.09996661 0.10286513
#   0.09928782 0.09782023 0.09935144 0.10023814]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09930335 0.099994   0.10083886 0.10036089 0.09994372 0.10283921
#   0.09926991 0.09781107 0.09937761 0.10026138]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09928302 0.09999677 0.10084309 0.10036353 0.09995871 0.10284704
#   0.09928162 0.09781863 0.09935635 0.10025125]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09925303 0.099994   0.10084322 0.10037419 0.099968   0.1028661
#   0.09929128 0.09782339 0.09934351 0.10024328]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09932959 0.09999848 0.10083492 0.10035006 0.09992881 0.10282961
#   0.09926197 0.09780663 0.09939156 0.10026836]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09927949 0.0999981  0.10084053 0.1003668  0.09995735 0.1028555
#   0.09928074 0.09781543 0.09935678 0.10024927]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09931454 0.09999435 0.10084036 0.10035651 0.0999402  0.10283681
#   0.09926664 0.09780638 0.09938427 0.10025993]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09929153 0.09999664 0.10084353 0.10036287 0.09995679 0.10284711
#   0.09927715 0.09781869 0.0993561  0.10024958]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09935166 0.09999832 0.10083452 0.1003493  0.09991767 0.10281353
#   0.09925534 0.09780908 0.0993945  0.10027609]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09935255 0.10000958 0.10083014 0.1003437  0.09991162 0.10281185
#   0.09925093 0.09777946 0.09942427 0.10028588]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09931618 0.09997698 0.10085126 0.10037141 0.09995299 0.10285047
#   0.09926707 0.09782253 0.09936216 0.10022894]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09932581 0.09998844 0.10083809 0.10036047 0.09993438 0.10284465
#   0.09925929 0.09780466 0.09939354 0.10025069]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09930006 0.09999547 0.10084171 0.10036542 0.09994554 0.10284615
#   0.09927263 0.09781134 0.09937078 0.10025091]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09933423 0.09998402 0.10084501 0.10036247 0.09993749 0.1028396
#   0.09925709 0.09780396 0.09938865 0.10024749]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09930235 0.09998242 0.10084973 0.10036828 0.09995258 0.10285837
#   0.09927326 0.0978122  0.09936856 0.10023225]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09932146 0.10000026 0.10083826 0.10035577 0.09993542 0.10283256
#   0.09926331 0.09780758 0.09938171 0.10026368]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.0992932  0.09999578 0.10084028 0.10036475 0.09995044 0.10284689
#   0.09927655 0.09781173 0.0993718  0.10024859]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09925696 0.0999924  0.10084568 0.10037248 0.09997256 0.10286238
#   0.09929371 0.09782731 0.09933883 0.10023768]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09930345 0.09999923 0.10083852 0.10036635 0.09994182 0.1028442
#   0.09926842 0.09780444 0.09938028 0.10025329]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09939099 0.09998514 0.1008386  0.10035015 0.09990772 0.10281699
#   0.09923455 0.09779118 0.09942413 0.10026055]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09934798 0.0999835  0.10084259 0.10036073 0.09993    0.10283468
#   0.09925346 0.09780233 0.09939552 0.1002492 ]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09928361 0.1000056  0.10082799 0.10035808 0.09994518 0.10285064
#   0.09927746 0.09780326 0.09938232 0.10026587]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09934186 0.10000156 0.10083117 0.10034516 0.09992372 0.10282256
#   0.09925462 0.09779913 0.09940316 0.10027707]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.0993164  0.09999993 0.10083625 0.1003524  0.09994558 0.10283024
#   0.09926494 0.09781173 0.09937728 0.10026524]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09930058 0.09999565 0.10083806 0.10036012 0.09994833 0.1028482
#   0.09926449 0.09780682 0.09938087 0.10025687]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09933226 0.10000562 0.10082945 0.10034268 0.09992616 0.10282362
#   0.09925939 0.09779681 0.0994057  0.10027832]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09931194 0.09998627 0.1008458  0.10036421 0.09994819 0.10283823
#   0.09927385 0.09781779 0.09936643 0.1002473 ]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.0993192  0.10000128 0.1008279  0.10035243 0.09992974 0.10284196
#   0.09926156 0.0977916  0.09940715 0.10026718]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09927222 0.09999156 0.10084654 0.10037084 0.09995997 0.10285537
#   0.09928332 0.09782413 0.09935056 0.10024549]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09924421 0.09999612 0.10083875 0.10037626 0.099972   0.10286882
#   0.09929835 0.097825   0.09933995 0.10024054]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09931228 0.10001687 0.10081853 0.10034375 0.09992692 0.10282966
#   0.09926472 0.09779371 0.09940719 0.10028637]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09925562 0.09999782 0.10084407 0.10036848 0.09997069 0.10286033
#   0.0992915  0.0978259  0.09933944 0.10024614]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09939633 0.09997195 0.10084971 0.10035461 0.09991486 0.10282131
#   0.09922527 0.09780252 0.09941487 0.10024859]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09928924 0.09999818 0.10084166 0.1003637  0.09995112 0.10284695
#   0.09927566 0.09780872 0.09937248 0.10025227]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09924946 0.09999473 0.10084587 0.10036996 0.09997148 0.10286253
#   0.09929199 0.09782583 0.09933975 0.1002484 ]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09932003 0.0999909  0.10083802 0.10036306 0.09993744 0.10284081
#   0.0992606  0.0978134  0.09938191 0.10025385]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09923986 0.09998857 0.10084901 0.10037947 0.09997822 0.10287444
#   0.09930087 0.09783086 0.09932729 0.10023141]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09932083 0.10000988 0.1008243  0.10034384 0.09992583 0.10283306
#   0.09925857 0.09778837 0.09941338 0.10028193]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09927605 0.10000901 0.1008283  0.10035885 0.09995275 0.10284818
#   0.09928413 0.09780763 0.09937079 0.10026431]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09931897 0.09999296 0.10083945 0.10035539 0.09993824 0.10283246
#   0.09926916 0.09781069 0.0993801  0.10026259]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09928259 0.1000019  0.10083622 0.10036022 0.09994882 0.10285033
#   0.09928002 0.09781515 0.09936606 0.10025869]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09924366 0.09999876 0.10083589 0.10037302 0.09997093 0.10287112
#   0.09929676 0.09781885 0.0993463  0.10024471]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09923275 0.09999876 0.10084194 0.10037817 0.09997199 0.10287417
#   0.09930398 0.09782554 0.09933338 0.10023932]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09929688 0.09998352 0.10084792 0.10036988 0.09995137 0.10285592
#   0.09927396 0.09781407 0.09936536 0.10024112]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09936333 0.09998403 0.10083961 0.10034996 0.09992279 0.10282286
#   0.09925007 0.09779584 0.09941047 0.10026106]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09926009 0.10000003 0.10084159 0.10037121 0.09996191 0.10285761
#   0.09928881 0.09782128 0.09934715 0.10025032]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09931516 0.1000058  0.10083251 0.10035074 0.09993243 0.1028298
#   0.09926679 0.09780654 0.09938526 0.10027498]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09926169 0.10000757 0.10083712 0.100365   0.09996323 0.10285494
#   0.09928652 0.09781391 0.09935447 0.10025554]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09931621 0.09999906 0.10083682 0.10035774 0.09993727 0.10283949
#   0.09926527 0.09780228 0.09938635 0.10025951]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09935524 0.09998655 0.10084759 0.10035548 0.09992299 0.10282369
#   0.09925033 0.09779939 0.09939933 0.10025942]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09926207 0.10000012 0.10084325 0.10037409 0.09996362 0.1028544
#   0.09929284 0.09781482 0.09934947 0.10024534]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.0992926  0.09998992 0.1008451  0.10037031 0.09995729 0.10285237
#   0.09927636 0.0978217  0.09935462 0.10023971]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09932136 0.09999696 0.10083664 0.10035354 0.09993956 0.10282764
#   0.09926539 0.09779964 0.09939638 0.10026289]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09925935 0.09998464 0.10084874 0.10037512 0.09997232 0.10286348
#   0.09929207 0.09782857 0.09934071 0.10023501]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09924101 0.10000218 0.10084499 0.10037236 0.0999765  0.10286523
#   0.09929975 0.09782634 0.09932891 0.10024273]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09931044 0.09999879 0.10083662 0.10035413 0.09993922 0.10283252
#   0.09926993 0.09780313 0.09938648 0.10026876]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09928147 0.09998231 0.10085557 0.10037741 0.09996523 0.10285581
#   0.0992854  0.09783022 0.09933656 0.10023004]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09929962 0.09999774 0.10083691 0.10036276 0.09994107 0.10283607
#   0.09927739 0.09781117 0.09937423 0.10026304]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09926578 0.09999659 0.10084325 0.10036749 0.09996235 0.10286016
#   0.09928981 0.09782328 0.09934769 0.1002436 ]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09926472 0.10000779 0.10083783 0.10036346 0.09996322 0.10284465
#   0.09929204 0.09781919 0.0993471  0.10025999]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09936518 0.09998102 0.10084092 0.10035785 0.09992038 0.10282677
#   0.0992469  0.09780291 0.09940607 0.10025201]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09936164 0.10000021 0.1008293  0.10034381 0.099912   0.10282151
#   0.09924538 0.09778348 0.09942949 0.10027318]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09928901 0.09999478 0.10084184 0.10036355 0.09995137 0.10284786
#   0.09927982 0.09781214 0.09936722 0.10025241]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09933545 0.10001384 0.10082296 0.10034043 0.09991904 0.10281986
#   0.09925291 0.09778474 0.09942061 0.10029017]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09929532 0.09998243 0.10085023 0.10037428 0.09995577 0.102855
#   0.09927746 0.09782171 0.09935722 0.10023058]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09934912 0.0999974  0.1008326  0.10034415 0.09992583 0.10282224
#   0.09925212 0.09779422 0.09940824 0.10027408]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09928732 0.09999293 0.10084197 0.10036587 0.09995146 0.10285928
#   0.09927398 0.09781925 0.09936111 0.10024683]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09928364 0.0999822  0.10085204 0.10037506 0.09996664 0.10285482
#   0.09928209 0.09782919 0.09934044 0.1002339 ]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09934218 0.10000942 0.10082377 0.1003324  0.09992022 0.10281294
#   0.09925928 0.09779266 0.09941693 0.10029021]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09933499 0.09999898 0.10082956 0.10034972 0.09993125 0.10282333
#   0.0992554  0.09780132 0.09940165 0.1002738 ]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09933087 0.10001112 0.10082113 0.10034252 0.09992001 0.10282955
#   0.09925647 0.09778929 0.09941606 0.10028299]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.0992691  0.09999458 0.10084443 0.10037042 0.09996285 0.10285646
#   0.09928615 0.09781944 0.09934974 0.10024683]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09932905 0.10000152 0.10083525 0.10035406 0.09992732 0.10282747
#   0.09926179 0.09781225 0.09938192 0.10026937]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09928392 0.09998509 0.10084629 0.1003701  0.09995904 0.10285769
#   0.09928132 0.09782042 0.09935632 0.10023982]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09933004 0.10000904 0.10082713 0.10034849 0.0999221  0.10282968
#   0.09925738 0.09778501 0.09941359 0.10027754]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09928802 0.09998646 0.10084867 0.1003692  0.09995622 0.10285245
#   0.09927972 0.09781897 0.09935832 0.10024196]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09927845 0.09999523 0.10084013 0.10036423 0.09995339 0.10284883
#   0.09928624 0.09781262 0.09936335 0.10025752]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09933384 0.10000145 0.10082869 0.10034516 0.09992312 0.1028297
#   0.09926273 0.09780169 0.09939788 0.10027573]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09928694 0.09998141 0.10084829 0.10037929 0.09995521 0.10286449
#   0.09927784 0.09781806 0.09935956 0.1002289 ]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09930061 0.09999498 0.10083826 0.10036307 0.09994783 0.10284591
#   0.09926989 0.09781101 0.0993765  0.10025194]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09926089 0.09998799 0.10085191 0.10037487 0.09997195 0.10285886
#   0.09929262 0.09782854 0.09933555 0.10023682]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09925874 0.09999557 0.10084403 0.10036973 0.09996699 0.10285716
#   0.09929199 0.09782292 0.09934569 0.10024718]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09932958 0.0999839  0.10084446 0.10036619 0.09993667 0.10283126
#   0.09926441 0.09782295 0.0993715  0.10024908]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09931091 0.09999167 0.10084015 0.10036232 0.09994052 0.10284302
#   0.09926978 0.0978038  0.09938116 0.10025668]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.0993767  0.09999827 0.10082541 0.10034167 0.0999038  0.10281414
#   0.09923741 0.09778402 0.09943777 0.1002808 ]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09927773 0.10000584 0.10083295 0.10036178 0.09995188 0.10285398
#   0.09927935 0.09780559 0.09937086 0.10026004]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09938181 0.0999954  0.10082576 0.10033736 0.09990446 0.10281438
#   0.09923725 0.09778028 0.09943861 0.1002847 ]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09930946 0.09998903 0.10083496 0.1003661  0.09994397 0.10284184
#   0.09926808 0.09781095 0.09938052 0.10025508]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09928088 0.09998622 0.10084941 0.10037223 0.09996421 0.10285514
#   0.0992801  0.09782621 0.09934788 0.10023772]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09934663 0.0999851  0.10084331 0.10035809 0.09992874 0.1028338
#   0.09925267 0.09780319 0.09939637 0.1002521 ]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09931382 0.09999469 0.1008364  0.10035527 0.09993843 0.10283611
#   0.09926994 0.09780465 0.0993853  0.10026539]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09932249 0.09997514 0.10085268 0.10037231 0.09994497 0.10285249
#   0.09926047 0.09782069 0.09936671 0.10023204]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09929341 0.09998742 0.10084762 0.10037373 0.09995389 0.1028503
#   0.09927412 0.09782769 0.0993539  0.10023794]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09930932 0.10001373 0.10082289 0.10034553 0.09993384 0.10282918
#   0.09927202 0.09779693 0.09939481 0.10028174]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09925851 0.09999716 0.10084159 0.10036992 0.09996747 0.10286175
#   0.09929049 0.09782501 0.09934255 0.10024554]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09926105 0.09999157 0.10084616 0.10037419 0.09996694 0.10286077
#   0.09928923 0.09781982 0.09934889 0.1002414 ]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09936005 0.10000801 0.10082201 0.10033858 0.09990921 0.10281986
#   0.09924277 0.09778037 0.09943601 0.10028313]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09929959 0.09999464 0.10084074 0.10036288 0.09994631 0.10284445
#   0.09927041 0.09781252 0.09937332 0.10025514]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09927368 0.10000096 0.10083911 0.10037366 0.09995973 0.10285768
#   0.09928361 0.09781685 0.09935264 0.10024206]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09934995 0.0999782  0.10084303 0.10036381 0.0999271  0.10283287
#   0.09925121 0.09780885 0.09938692 0.10025805]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09930283 0.09998751 0.10084152 0.10037164 0.09995171 0.1028498
#   0.09926932 0.09781458 0.09936895 0.10024214]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09927688 0.10000657 0.10083429 0.10035927 0.09995165 0.10284657
#   0.09928133 0.09781342 0.09936743 0.10026259]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09932827 0.09997608 0.10085471 0.10036946 0.09994535 0.10284415
#   0.09926355 0.09781867 0.09936899 0.10023077]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09930769 0.09998663 0.10084309 0.10036303 0.09994534 0.10284753
#   0.09927041 0.09781109 0.0993766  0.10024858]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09937535 0.09999919 0.10082811 0.10034214 0.09990522 0.10281443
#   0.09923863 0.09778591 0.09943105 0.10027998]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09933807 0.09998332 0.10084206 0.10035923 0.0999307  0.1028354
#   0.09925512 0.09781022 0.09938453 0.10026135]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09934529 0.10000277 0.10082231 0.10034542 0.09992014 0.10283038
#   0.09924817 0.09778325 0.09942634 0.10027594]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09931013 0.09999519 0.10084112 0.10036033 0.09994284 0.10283988
#   0.0992688  0.09780921 0.0993766  0.1002559 ]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09926737 0.09997886 0.10085049 0.10038358 0.09996847 0.10287162
#   0.09928543 0.09782606 0.09934423 0.10022389]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09930711 0.09998762 0.10083912 0.1003681  0.09994243 0.10285114
#   0.09926839 0.09780632 0.09938238 0.10024739]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09929479 0.10000896 0.1008301  0.10035393 0.09994496 0.10283878
#   0.09927312 0.09780261 0.09938362 0.10026913]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09927759 0.10000257 0.10083646 0.10036274 0.09995452 0.10284703
#   0.09928174 0.09782098 0.0993595  0.10025687]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09927399 0.09997168 0.10086072 0.10038494 0.09997    0.10286382
#   0.0992865  0.09783294 0.09933564 0.10021977]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09929996 0.09999232 0.10084444 0.10036267 0.09994937 0.10284449
#   0.09927285 0.09781415 0.09936766 0.10025208]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09933404 0.09998658 0.100844   0.1003587  0.09993187 0.10283372
#   0.09925838 0.0978119  0.09938418 0.10025663]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09929833 0.10000396 0.10082643 0.10035423 0.09994134 0.10284158
#   0.0992675  0.09780203 0.09939138 0.10027323]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09926453 0.09999868 0.10084247 0.1003729  0.09996454 0.10285852
#   0.09929116 0.09782006 0.09934741 0.10023973]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09925564 0.09998139 0.1008589  0.1003905  0.09997526 0.10287244
#   0.09929117 0.09783568 0.09932273 0.10021628]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09929969 0.09999201 0.10084302 0.10036349 0.09995221 0.10284253
#   0.09927436 0.09781686 0.09936413 0.10025171]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09935924 0.09999067 0.10083815 0.10034958 0.09991792 0.10282143
#   0.0992505  0.09780041 0.09940598 0.1002661 ]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.0993344  0.099994   0.10082925 0.10035393 0.09992983 0.10283788
#   0.09925539 0.09779352 0.09941045 0.10026136]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09930228 0.09998931 0.10084422 0.10036568 0.09994815 0.1028457
#   0.09927223 0.09781075 0.09937025 0.10025145]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09930521 0.10001014 0.10082804 0.10035675 0.09993779 0.10283133
#   0.09926401 0.09780264 0.0993853  0.10027879]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.0992776  0.0999987  0.10083728 0.10036779 0.09995708 0.10285569
#   0.09927982 0.09781214 0.0993654  0.10024849]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09931952 0.09998998 0.10084286 0.10035906 0.09993593 0.10284184
#   0.09925825 0.09780025 0.09939295 0.10025938]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09927904 0.09999504 0.10084379 0.10036486 0.09995968 0.10285032
#   0.09928256 0.09781928 0.0993562  0.10024923]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.0992749  0.10000099 0.10083704 0.100363   0.09995477 0.10284936
#   0.09928347 0.09781582 0.09936058 0.10026008]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09935272 0.09998206 0.10084703 0.10035448 0.0999306  0.1028292
#   0.09925035 0.09780498 0.0993963  0.10025229]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09933884 0.09998526 0.10084454 0.1003544  0.09993571 0.10283661
#   0.09925511 0.09780353 0.09939543 0.10025058]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09927831 0.09999526 0.10083766 0.1003617  0.09995724 0.10285213
#   0.09928284 0.09781312 0.0993642  0.10025754]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09932434 0.09999452 0.10083579 0.10035675 0.09993945 0.10284105
#   0.09926062 0.09780151 0.09939092 0.10025505]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09925426 0.1000132  0.10083187 0.10035956 0.09995805 0.10286565
#   0.09928921 0.09780501 0.09936447 0.10025871]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.0992757  0.09999475 0.10084289 0.10036457 0.09995844 0.10285746
#   0.09928571 0.09781534 0.09935755 0.1002476 ]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09930508 0.09998823 0.1008464  0.10036391 0.09995178 0.10284104
#   0.09927123 0.09781424 0.09936732 0.10025077]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09933469 0.10000817 0.10082689 0.1003433  0.09992409 0.1028201
#   0.09925605 0.09779492 0.09940989 0.1002819 ]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09929459 0.1000075  0.10083268 0.10035676 0.09993991 0.10283801
#   0.09927078 0.09780338 0.0993837  0.10027269]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09937262 0.0999797  0.10084706 0.10035431 0.09991738 0.10281873
#   0.09924577 0.09780547 0.099401   0.10025795]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09931979 0.10000104 0.1008322  0.10035122 0.09993112 0.10283616
#   0.09926494 0.09779817 0.09939827 0.10026709]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09938218 0.09997627 0.10085043 0.10035294 0.09991432 0.10281934
#   0.09923254 0.09779157 0.09942096 0.10025946]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09923718 0.10000632 0.10083815 0.10036962 0.09997388 0.10286904
#   0.0992979  0.09781964 0.09934247 0.10024581]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.0992459  0.09999313 0.10084772 0.10037436 0.09997566 0.10286522
#   0.0992963  0.09783076 0.09932783 0.10024312]]
# Prediction: 5
# Target: 4
# False
# Predictions: [[0.09928494 0.09999432 0.10084269 0.10036949 0.0999575  0.10285516
#   0.09927822 0.09781987 0.09935438 0.10024344]]
# Prediction: 5
# Target: 6
# False
# Predictions: [[0.09926652 0.10000304 0.10083749 0.10036679 0.09995993 0.10285771
#   0.09928719 0.09781476 0.0993543  0.10025226]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09931177 0.10000181 0.10083307 0.1003472  0.09993916 0.10283223
#   0.09926902 0.09780836 0.09938906 0.10026833]]
# Prediction: 5
# Target: 1
# False
# Predictions: [[0.09935285 0.09997889 0.10084639 0.10036412 0.09993275 0.10283879
#   0.09925029 0.09781145 0.09938392 0.10024056]]
# Prediction: 5
# Target: 0
# False
# Predictions: [[0.09929393 0.09999393 0.10084454 0.10036468 0.09995153 0.10284542
#   0.09927638 0.09781516 0.09936343 0.10025099]]
# Prediction: 5
# Target: 7
# False
# Predictions: [[0.09929438 0.09998921 0.10084887 0.10036809 0.09995265 0.10284723
#   0.09927549 0.09781767 0.09936246 0.10024396]]
# Prediction: 5
# Target: 2
# False
# Predictions: [[0.09928623 0.0999934  0.10084109 0.10036197 0.09995322 0.10284964
#   0.09928069 0.09781333 0.09936652 0.10025393]]
# Prediction: 5
# Target: 7
# False
# 0
